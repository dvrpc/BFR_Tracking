# %% [markdown]
# # Test `scrape_packages.py`
#
# This notebook facilitates the testing of the `scrape_packages.py` script within an interactive notebook.
#
# We'll start off by importing functions from the script and building a list of PDF files for the test.

# %%
from pathlib import Path

from scripts.scrape_packages import (
    read_single_page_from_pdf,
    extract_data_from_columns,
    parse_single_page
)

# %%
data_folder = Path("../data")
paving_package = data_folder / "paving_package"

filepaths = [x for x in paving_package.rglob("*.pdf")]

# %% [markdown]
# ## Read the raw data
#
# The function `read_single_page_from_pdf()` reads a page from the PDF and makes a few minimal changes, including dropping the first two header rows and the total row (if present).

# %%
test_file = filepaths[1]

df = read_single_page_from_pdf(test_file, page_number=1)

df
# Out:
#   project_num                  SR_name  \
# 2           1  SR 1013\rSpringfield Rd
# 3           2      SR 2002\r2nd Street
# 4           3  SR 2009\rSpringfield Rd
# 5           4     SR 2013\rClifton Ave
# 6           5    SR 2016\rBaltimore Pk
# 7           6      SR 2028\rMorton Ave
# 8           7     SR 2031\rSellers Ave
# 9           8   SR 2037\rCrum Creek Rd
#
#                                             from  \
# 2      0010/0000\r0011/0000\rSproul Rd / SR 0320
# 3            0010/0000\rIndustrial Hwy / SR 0291
# 4                      0080/0000\rNetherwood Dr.
# 5                   0010/0000\rHook Rd / SR 2015
# 6  0060/0000\r0061/0000\rProvidence Rd / SR 0252
# 7                 0010/0000\rFourth St / SR 0291
# 8                        0034/0000\rFairmount Rd
# 9                 0010/0000\rBeatty Rd / SR 2018
#
#                                                 to                   scope  \
# 2  0020/1115\r0021/1170\rWest Chester Pk / SR 0003  Mill &\r1 1/2" Overlay
# 3                  0040/2604\rFourth Ave / SR 2029  Mill &\r1 1/2" Overlay
# 4                   0130/1670\rSproul Rd / SR 0320  Mill &\r1 1/2" Overlay
# 5              0060/2830\rSpringfield Rd / SR 2009  Mill &\r1 1/2" Overlay
# 6          0140/3471\r0141/3461\rOak Ave / SR 2015  Mill &\r1 1/2" Overlay
# 7                    0010/1636\rNinth St / SR 0013  Mill &\r1 1/2" Overlay
# 8      0040/2186\rWard Ave / Ridley Ave /\rSR 2004  Mill &\r1 1/2" Overlay
# 9                    0020/2785\rState Rd / SR 1008  Mill &\r1 1/2" Overlay
#
#         miles                                 muni     adt
# 2  0.80\r0.82                               Marple  15,000
# 3        1.53                              Tinicum   5,800
# 4        2.48                  Marple, Springfield  18,843
# 5        2.26  Sharon Hill B.,\rCollingdale, Aldan   9,000
# 6  4.36\r4.35           Swarthmore, Morton,\rMedia  34,000
# 7        0.31                         Chester City   7,600
# 8        0.64                  Ridley Park, Ridley   9,300
# 9        1.09    U. Providence,\rNether Providence     328

# %% [markdown]
# ## Parse data from source columns into additional new columns
#
# The function `extract_data_from_columns()` gets data from columns like `muni`, `from`, `to`, `fsegment`, and `tsegment`

# %%
df = extract_data_from_columns(df)

df
# Out:
#   project_num                  SR_name                                from  \
# 2           1  SR 1013\rSpringfield Rd      0011/0000\rSproul Rd / SR 0320
# 3           2      SR 2002\r2nd Street            Industrial Hwy / SR 0291
# 4           3  SR 2009\rSpringfield Rd                      Netherwood Dr.
# 5           4     SR 2013\rClifton Ave                   Hook Rd / SR 2015
# 6           5    SR 2016\rBaltimore Pk  0061/0000\rProvidence Rd / SR 0252
# 7           6      SR 2028\rMorton Ave                 Fourth St / SR 0291
# 8           7     SR 2031\rSellers Ave                        Fairmount Rd
# 9           8   SR 2037\rCrum Creek Rd                 Beatty Rd / SR 2018
#
#                                      to                   scope       miles  \
# 2  0021/1170\rWest Chester Pk / SR 0003  Mill &\r1 1/2" Overlay  0.80\r0.82
# 3                  Fourth Ave / SR 2029  Mill &\r1 1/2" Overlay        1.53
# 4                   Sproul Rd / SR 0320  Mill &\r1 1/2" Overlay        2.48
# 5              Springfield Rd / SR 2009  Mill &\r1 1/2" Overlay        2.26
# 6          0141/3461\rOak Ave / SR 2015  Mill &\r1 1/2" Overlay  4.36\r4.35
# 7                    Ninth St / SR 0013  Mill &\r1 1/2" Overlay        0.31
# 8      Ward Ave / Ridley Ave /\rSR 2004  Mill &\r1 1/2" Overlay        0.64
# 9                    State Rd / SR 1008  Mill &\r1 1/2" Overlay        1.09
#
#                                   muni     adt    sr            name  \
# 2                               Marple  15,000  1013  Springfield Rd
# 3                              Tinicum   5,800  2002      2nd Street
# 4                  Marple, Springfield  18,843  2009  Springfield Rd
# 5  Sharon Hill B.,\rCollingdale, Aldan   9,000  2013     Clifton Ave
# 6           Swarthmore, Morton,\rMedia  34,000  2016    Baltimore Pk
# 7                         Chester City   7,600  2028      Morton Ave
# 8                  Ridley Park, Ridley   9,300  2031     Sellers Ave
# 9    U. Providence,\rNether Providence     328  2037   Crum Creek Rd
#
#             muni1                muni2    muni3 fsegment foffset tsegment  \
# 2          Marple                 None     None     0010    0000     0020
# 3         Tinicum                 None     None     0010    0000     0040
# 4          Marple          Springfield     None     0080    0000     0130
# 5  Sharon Hill B.        \rCollingdale    Aldan     0010    0000     0060
# 6      Swarthmore               Morton  \rMedia     0060    0000     0140
# 7    Chester City                 None     None     0010    0000     0010
# 8     Ridley Park               Ridley     None     0034    0000     0040
# 9   U. Providence  \rNether Providence     None     0010    0000     0020
#
#   toffset
# 2    1115
# 3    2604
# 4    1670
# 5    2830
# 6    3471
# 7    1636
# 8    2186
# 9    2785

# %% [markdown]
# ## Explode grouped rows into two
#
# The function `parse_single_page()` runs through each row and turns any grouped rows into two rows. Inside this function the previous two functions are called: `read_single_page_from_pdf()` and `extract_data_from_columns()`

# %%
df = parse_single_page(test_file, page_number=1)

df
# Out:
#   project_num                  SR_name                                from  \
# 0           1  SR 1013\rSpringfield Rd                 Sproul Rd / SR 0320
# 1           2      SR 2002\r2nd Street            Industrial Hwy / SR 0291
# 2           3  SR 2009\rSpringfield Rd                      Netherwood Dr.
# 3           4     SR 2013\rClifton Ave                   Hook Rd / SR 2015
# 4           5    SR 2016\rBaltimore Pk  0061/0000\rProvidence Rd / SR 0252
# 5           6      SR 2028\rMorton Ave                 Fourth St / SR 0291
# 6           7     SR 2031\rSellers Ave                        Fairmount Rd
# 7           8   SR 2037\rCrum Creek Rd                 Beatty Rd / SR 2018
# 8           1  SR 1013\rSpringfield Rd                 Sproul Rd / SR 0320
# 9           5    SR 2016\rBaltimore Pk             Providence Rd / SR 0252
#
#                                  to                   scope       miles  \
# 0         West Chester Pk / SR 0003  Mill &\r1 1/2" Overlay        0.80
# 1              Fourth Ave / SR 2029  Mill &\r1 1/2" Overlay        1.53
# 2               Sproul Rd / SR 0320  Mill &\r1 1/2" Overlay        2.48
# 3          Springfield Rd / SR 2009  Mill &\r1 1/2" Overlay        2.26
# 4      0141/3461\rOak Ave / SR 2015  Mill &\r1 1/2" Overlay  4.36\r4.35
# 5                Ninth St / SR 0013  Mill &\r1 1/2" Overlay        0.31
# 6  Ward Ave / Ridley Ave /\rSR 2004  Mill &\r1 1/2" Overlay        0.64
# 7                State Rd / SR 1008  Mill &\r1 1/2" Overlay        1.09
# 8         West Chester Pk / SR 0003  Mill &\r1 1/2" Overlay        0.82
# 9                 Oak Ave / SR 2015  Mill &\r1 1/2" Overlay        4.35
#
#                                   muni     adt    sr            name  \
# 0                               Marple  15,000  1013  Springfield Rd
# 1                              Tinicum   5,800  2002      2nd Street
# 2                  Marple, Springfield  18,843  2009  Springfield Rd
# 3  Sharon Hill B.,\rCollingdale, Aldan   9,000  2013     Clifton Ave
# 4           Swarthmore, Morton,\rMedia  34,000  2016    Baltimore Pk
# 5                         Chester City   7,600  2028      Morton Ave
# 6                  Ridley Park, Ridley   9,300  2031     Sellers Ave
# 7    U. Providence,\rNether Providence     328  2037   Crum Creek Rd
# 8                               Marple  15,000  1013  Springfield Rd
# 9           Swarthmore, Morton,\rMedia  34,000  2016    Baltimore Pk
#
#             muni1                muni2    muni3 fsegment foffset tsegment  \
# 0          Marple                 None     None     0010    0000     0020
# 1         Tinicum                 None     None     0010    0000     0040
# 2          Marple          Springfield     None     0080    0000     0130
# 3  Sharon Hill B.        \rCollingdale    Aldan     0010    0000     0060
# 4      Swarthmore               Morton  \rMedia     0060    0000     0140
# 5    Chester City                 None     None     0010    0000     0010
# 6     Ridley Park               Ridley     None     0034    0000     0040
# 7   U. Providence  \rNether Providence     None     0010    0000     0020
# 8          Marple                 None     None     0011    0000     0021
# 9      Swarthmore               Morton  \rMedia     0061    0000     0141
#
#   toffset
# 0    1115
# 1    2604
# 2    1670
# 3    2830
# 4    3471
# 5    1636
# 6    2186
# 7    2785
# 8    1170
# 9    3461
